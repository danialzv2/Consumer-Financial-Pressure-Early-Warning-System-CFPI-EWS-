# %%
import pandas as pd

BASE_PATH = "../data"

def load_historical_data():
    """
    Loads historical macro + CFPI data.
    """
    df = pd.read_csv(
        f"{BASE_PATH}/data.csv",
        parse_dates=["date"]
    )
    df.columns = df.columns.str.lower().str.strip()

    return df

def load_forecast_data():
    """
    Loads ML CFPI direction forecast.
    """
    df = pd.read_csv(
        f"{BASE_PATH}/cfpi_direction_forecast.csv",
        parse_dates=["date"]
    )
    df.columns = df.columns.str.lower().str.strip()

    return df

# %%
import numpy as np 
hist_df = load_historical_data()
forecast_df = load_forecast_data()

hist_df["state"] = hist_df["state"].astype(str).str.lower()
forecast_df["state"] = forecast_df["state"].astype(str).str.lower()

def get_all_states():
    return sorted(hist_df["state"].dropna().unique().tolist())


def get_historical_timeseries(state_name: str):
    state_name = state_name.lower()
    df = hist_df[hist_df["state"] == state_name].sort_values("date")

    # Convert Timestamp -> string
    df["date"] = df["date"].dt.strftime("%Y-%m-%d")

    # Convert NaN -> None
    df = df.replace({np.nan: None})

    return df.to_dict(orient="records")

def get_latest_forecast_by_state(state_name: str):
    return (
        forecast_df[forecast_df["state"].str.lower() == state_name.lower()]
        .sort_values("date")
        .tail(1)
    )

def get_state_dashboard_view(state_name: str):
    return {
        "historical": get_historical_timeseries(state_name),
        "latest_forecast": get_latest_forecast_by_state(state_name)
    }

def historical_state(state_name: str):
   return get_historical_timeseries(state_name)

historical_state("Terengganu")
# Out:
# [{'date': '2017-04-01',
#   'ron95': 2.13,
#   'ron97': 2.41,
#   'diesel': 2.11,
#   'ron95_budi95': 2.13,
#   'usd': 4.4265,
#   'index': 115.9,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': None,
#   'inflation_pressure': None,
#   'fx_pressure': None,
#   'policy_pressure': 0,
#   'raw_cfpi': None,
#   'cfpi': None,
#   'cfpi_trend': None,
#   'risk_flag': None},
#  {'date': '2017-05-01',
#   'ron95': 2.21,
#   'ron97': 2.49,
#   'diesel': 2.14,
#   'ron95_budi95': 2.21,
#   'usd': 4.3475,
#   'index': 115.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': None,
#   'inflation_pressure': None,
#   'fx_pressure': None,
#   'policy_pressure': 0,
#   'raw_cfpi': None,
#   'cfpi': None,
#   'cfpi_trend': None,
#   'risk_flag': None},
#  {'date': '2017-06-01',
#   'ron95': 2.1,
#   'ron97': 2.38,
#   'diesel': 2.02,
#   'ron95_budi95': 2.1,
#   'usd': 4.289,
#   'index': 115.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': None,
#   'inflation_pressure': None,
#   'fx_pressure': None,
#   'policy_pressure': 0,
#   'raw_cfpi': None,
#   'cfpi': None,
#   'cfpi_trend': None,
#   'risk_flag': None},
#  {'date': '2017-07-01',
#   'ron95': 1.89,
#   'ron97': 2.15,
#   'diesel': 1.84,
#   'ron95_budi95': 1.89,
#   'usd': 4.294,
#   'index': 115.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': None,
#   'inflation_pressure': None,
#   'fx_pressure': None,
#   'policy_pressure': 0,
#   'raw_cfpi': None,
#   'cfpi': None,
#   'cfpi_trend': None,
#   'risk_flag': None},
#  {'date': '2017-08-01',
#   'ron95': 2.03,
#   'ron97': 2.28,
#   'diesel': 1.99,
#   'ron95_budi95': 2.03,
#   'usd': 4.2775,
#   'index': 116.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': None,
#   'inflation_pressure': None,
#   'fx_pressure': None,
#   'policy_pressure': 0,
#   'raw_cfpi': None,
#   'cfpi': None,
#   'cfpi_trend': None,
#   'risk_flag': None},
#  {'date': '2017-09-01',
#   'ron95': 2.16,
#   'ron97': 2.44,
#   'diesel': 2.04,
#   'ron95_budi95': 2.16,
#   'usd': 4.2695,
#   'index': 116.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': None,
#   'inflation_pressure': None,
#   'fx_pressure': None,
#   'policy_pressure': 0,
#   'raw_cfpi': None,
#   'cfpi': None,
#   'cfpi_trend': None,
#   'risk_flag': None},
#  {'date': '2017-10-01',
#   'ron95': 2.16,
#   'ron97': 2.46,
#   'diesel': 2.12,
#   'ron95_budi95': 2.16,
#   'usd': 4.2275,
#   'index': 116.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 0.137655088869618,
#   'inflation_pressure': None,
#   'fx_pressure': None,
#   'policy_pressure': 0,
#   'raw_cfpi': None,
#   'cfpi': None,
#   'cfpi_trend': None,
#   'risk_flag': None},
#  {'date': '2017-11-01',
#   'ron95': 2.2,
#   'ron97': 2.5,
#   'diesel': 2.13,
#   'ron95_budi95': 2.2,
#   'usd': 4.2335,
#   'index': 117.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 0.1995554133323755,
#   'inflation_pressure': None,
#   'fx_pressure': None,
#   'policy_pressure': 0,
#   'raw_cfpi': None,
#   'cfpi': None,
#   'cfpi_trend': None,
#   'risk_flag': None},
#  {'date': '2017-12-01',
#   'ron95': 2.3,
#   'ron97': 2.58,
#   'diesel': 2.25,
#   'ron95_budi95': 2.3,
#   'usd': 4.087,
#   'index': 117.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 0.4690974477788535,
#   'inflation_pressure': None,
#   'fx_pressure': -1.631538205736701,
#   'policy_pressure': 0,
#   'raw_cfpi': None,
#   'cfpi': None,
#   'cfpi_trend': None,
#   'risk_flag': None},
#  {'date': '2018-01-01',
#   'ron95': 2.26,
#   'ron97': 2.53,
#   'diesel': 2.26,
#   'ron95_budi95': 2.26,
#   'usd': 4.062,
#   'index': 118.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -1.3633547117622544,
#   'inflation_pressure': None,
#   'fx_pressure': -1.127381991614233,
#   'policy_pressure': 0,
#   'raw_cfpi': None,
#   'cfpi': None,
#   'cfpi_trend': None,
#   'risk_flag': None},
#  {'date': '2018-02-01',
#   'ron95': 2.31,
#   'ron97': 2.58,
#   'diesel': 2.34,
#   'ron95_budi95': 2.31,
#   'usd': 3.8945,
#   'index': 118.1,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': 0.0865384311444102,
#   'inflation_pressure': None,
#   'fx_pressure': -1.703215831225777,
#   'policy_pressure': 1,
#   'raw_cfpi': None,
#   'cfpi': None,
#   'cfpi_trend': None,
#   'risk_flag': None},
#  {'date': '2018-03-01',
#   'ron95': 2.2,
#   'ron97': 2.47,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 3.9305,
#   'index': 117.4,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': -1.7108202592479491,
#   'inflation_pressure': None,
#   'fx_pressure': -0.0250174207041635,
#   'policy_pressure': 0,
#   'raw_cfpi': None,
#   'cfpi': None,
#   'cfpi_trend': None,
#   'risk_flag': None},
#  {'date': '2018-04-01',
#   'ron95': 2.2,
#   'ron97': 2.47,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 3.862,
#   'index': 117.1,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': -0.1025680916200897,
#   'inflation_pressure': None,
#   'fx_pressure': -0.2645519169737071,
#   'policy_pressure': 0,
#   'raw_cfpi': None,
#   'cfpi': None,
#   'cfpi_trend': None,
#   'risk_flag': None},
#  {'date': '2018-05-01',
#   'ron95': 2.2,
#   'ron97': 2.47,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 3.9195,
#   'index': 117.3,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': -0.0340046338494196,
#   'inflation_pressure': None,
#   'fx_pressure': 1.6900721194879411,
#   'policy_pressure': 0,
#   'raw_cfpi': None,
#   'cfpi': None,
#   'cfpi_trend': None,
#   'risk_flag': None},
#  {'date': '2018-06-01',
#   'ron95': 2.2,
#   'ron97': 2.47,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 3.9835,
#   'index': 116.1,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': 0.2508394539864767,
#   'inflation_pressure': None,
#   'fx_pressure': 1.263270988541411,
#   'policy_pressure': 0,
#   'raw_cfpi': None,
#   'cfpi': None,
#   'cfpi_trend': None,
#   'risk_flag': None},
#  {'date': '2018-07-01',
#   'ron95': 2.2,
#   'ron97': 2.5,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 4.0385,
#   'index': 116.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': 0.2616404929750308,
#   'inflation_pressure': None,
#   'fx_pressure': 1.3441319808599737,
#   'policy_pressure': 0,
#   'raw_cfpi': None,
#   'cfpi': None,
#   'cfpi_trend': None,
#   'risk_flag': None},
#  {'date': '2018-08-01',
#   'ron95': 2.2,
#   'ron97': 2.54,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 4.0655,
#   'index': 116.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': 0.5117234743256671,
#   'inflation_pressure': None,
#   'fx_pressure': 0.8928212360922975,
#   'policy_pressure': 0,
#   'raw_cfpi': None,
#   'cfpi': None,
#   'cfpi_trend': None,
#   'risk_flag': None},
#  {'date': '2018-09-01',
#   'ron95': 2.2,
#   'ron97': 2.69,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 4.1075,
#   'index': 116.3,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': 1.9466179460353383,
#   'inflation_pressure': -1.1515844419164916,
#   'fx_pressure': 0.4951954938527114,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.2799699279103718,
#   'cfpi': 66.13188809233725,
#   'cfpi_trend': None,
#   'risk_flag': 'High'},
#  {'date': '2018-10-01',
#   'ron95': 2.2,
#   'ron97': 2.79,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 4.1415,
#   'index': 116.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': 0.7629297891613902,
#   'inflation_pressure': -0.5518677746124766,
#   'fx_pressure': -0.0732911213929878,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.1505184596329122,
#   'cfpi': 60.22718849344725,
#   'cfpi_trend': -5.904699598889998,
#   'risk_flag': 'High'},
#  {'date': '2018-11-01',
#   'ron95': 2.2,
#   'ron97': 2.81,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 4.1845,
#   'index': 117.0,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': -0.6508818516466819,
#   'inflation_pressure': -0.8393439218082628,
#   'fx_pressure': -0.1027707773547247,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.0695173881106723,
#   'cfpi': 50.19064275780345,
#   'cfpi_trend': -10.0365457356438,
#   'risk_flag': 'Moderate'},
#  {'date': '2018-12-01',
#   'ron95': 2.2,
#   'ron97': 2.5,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 4.188,
#   'index': 117.1,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': -1.9402533045082453,
#   'inflation_pressure': -0.9808514150754446,
#   'fx_pressure': -1.2926452432561495,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.5574750425074994,
#   'cfpi': 27.933318028069657,
#   'cfpi_trend': -22.2573247297338,
#   'risk_flag': 'Low'},
#  {'date': '2019-01-01',
#   'ron95': 2.2,
#   'ron97': 2.5,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 4.1385,
#   'index': 116.4,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': -0.0059117440809481,
#   'inflation_pressure': -1.9563711149228733,
#   'fx_pressure': -1.832201616555236,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.9154786185454292,
#   'cfpi': 11.603618566480543,
#   'cfpi_trend': -16.32969946158911,
#   'risk_flag': 'Low'},
#  {'date': '2019-02-01',
#   'ron95': 1.98,
#   'ron97': 2.28,
#   'diesel': 2.18,
#   'ron95_budi95': 1.98,
#   'usd': 4.089,
#   'index': 116.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': -1.822955805001532,
#   'inflation_pressure': -1.0938840257990885,
#   'fx_pressure': -1.7150873501526618,
#   'policy_pressure': 0,
#   'raw_cfpi': -1.169870130866373,
#   'cfpi': 0.0,
#   'cfpi_trend': -11.603618566480543,
#   'risk_flag': 'Low'},
#  {'date': '2019-03-01',
#   'ron95': 2.08,
#   'ron97': 2.38,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.073,
#   'index': 116.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': 1.1955878946674263,
#   'inflation_pressure': 0.2067939128150053,
#   'fx_pressure': -1.2641615231796568,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.7158284746898206,
#   'cfpi': 20.71030650157454,
#   'cfpi_trend': 20.71030650157454,
#   'risk_flag': 'Low'},
#  {'date': '2019-04-01',
#   'ron95': 2.08,
#   'ron97': 2.63,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.076,
#   'index': 116.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': 0.791867160659254,
#   'inflation_pressure': 0.8460082673163948,
#   'fx_pressure': -0.5267540997035018,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.2220764884977702,
#   'cfpi': 43.23192942029264,
#   'cfpi_trend': 22.521622918718094,
#   'risk_flag': 'Moderate'},
#  {'date': '2019-05-01',
#   'ron95': 2.08,
#   'ron97': 2.81,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.1355,
#   'index': 117.0,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': 0.525973320678923,
#   'inflation_pressure': 1.0701867701320362,
#   'fx_pressure': 0.9052212038605644,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.4399785871964549,
#   'cfpi': 73.43039987345061,
#   'cfpi_trend': 30.198470453157974,
#   'risk_flag': 'High'},
#  {'date': '2019-06-01',
#   'ron95': 2.08,
#   'ron97': 2.63,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.197,
#   'index': 117.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.3797418121550271,
#   'inflation_pressure': 1.6825478178222173,
#   'fx_pressure': 1.5546522194100116,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.6425378216043622,
#   'cfpi': 82.66978082505389,
#   'cfpi_trend': 9.23938095160328,
#   'risk_flag': 'Severe'},
#  {'date': '2019-07-01',
#   'ron95': 2.08,
#   'ron97': 2.49,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.1335,
#   'index': 117.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.230684350701201,
#   'inflation_pressure': 1.1252392451715745,
#   'fx_pressure': 0.6695814425446204,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.6526153207012958,
#   'cfpi': 83.12944810938272,
#   'cfpi_trend': 0.4596672843288303,
#   'risk_flag': 'Severe'},
#  {'date': '2019-08-01',
#   'ron95': 2.08,
#   'ron97': 2.56,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.1445,
#   'index': 117.4,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.1023733138196017,
#   'inflation_pressure': 1.0065761462640994,
#   'fx_pressure': -0.0197004293949309,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.520697975583151,
#   'cfpi': 77.11227190295901,
#   'cfpi_trend': -6.017176206423713,
#   'risk_flag': 'High'},
#  {'date': '2019-09-01',
#   'ron95': 2.08,
#   'ron97': 2.5,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.222,
#   'index': 117.3,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4656713966705832,
#   'inflation_pressure': 0.5412197537706321,
#   'fx_pressure': -0.1468872733818106,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.2655141101394557,
#   'cfpi': 65.47251155123378,
#   'cfpi_trend': -11.63976035172523,
#   'risk_flag': 'High'},
#  {'date': '2019-10-01',
#   'ron95': 2.08,
#   'ron97': 2.79,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.192,
#   'index': 117.4,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 1.4259395788414324,
#   'inflation_pressure': 0.1457151615225863,
#   'fx_pressure': 0.1145352847159638,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.2798956161460933,
#   'cfpi': 66.12849849274006,
#   'cfpi_trend': 0.6559869415062849,
#   'risk_flag': 'High'},
#  {'date': '2019-11-01',
#   'ron95': 2.08,
#   'ron97': 2.59,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.172,
#   'index': 117.3,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.8609580029316706,
#   'inflation_pressure': -1.9328636515150703,
#   'fx_pressure': -0.5550907116065689,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.1745901813201259,
#   'cfpi': 45.39793327235884,
#   'cfpi_trend': -20.730565220381223,
#   'risk_flag': 'Moderate'},
#  {'date': '2019-12-01',
#   'ron95': 2.08,
#   'ron97': 2.66,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.1713,
#   'index': 117.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 0.3605237925581582,
#   'inflation_pressure': -0.7209956219581978,
#   'fx_pressure': -1.7767627849741747,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.3478874903384395,
#   'cfpi': 37.49328325436189,
#   'cfpi_trend': -7.904650017996957,
#   'risk_flag': 'Moderate'},
#  {'date': '2020-01-01',
#   'ron95': 2.08,
#   'ron97': 2.63,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.0925,
#   'index': 117.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.3302482326145,
#   'inflation_pressure': 1.2470145945511515,
#   'fx_pressure': -1.6105886099835311,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.5100295972773332,
#   'cfpi': 30.097458034726497,
#   'cfpi_trend': -7.3958252196353875,
#   'risk_flag': 'Moderate'},
#  {'date': '2020-02-01',
#   'ron95': 2.08,
#   'ron97': 2.41,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.0885,
#   'index': 117.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': -1.034917615365508,
#   'inflation_pressure': 0.9177915630389796,
#   'fx_pressure': -0.9608831698898536,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.2219019473749633,
#   'cfpi': 43.23989080467506,
#   'cfpi_trend': 13.142432769948568,
#   'risk_flag': 'Moderate'},
#  {'date': '2020-03-01',
#   'ron95': 2.08,
#   'ron97': 2.4,
#   'diesel': 2.13,
#   'ron95_budi95': 2.08,
#   'usd': 4.226,
#   'index': 115.9,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': -0.3060102991193275,
#   'inflation_pressure': -1.7215377867488708,
#   'fx_pressure': 0.9857231723125088,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.2211195452825115,
#   'cfpi': 43.27557869128574,
#   'cfpi_trend': 0.035687886610674,
#   'risk_flag': 'Moderate'},
#  {'date': '2020-04-01',
#   'ron95': 1.38,
#   'ron97': 1.68,
#   'diesel': 1.68,
#   'ron95_budi95': 1.38,
#   'usd': 4.3275,
#   'index': 112.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.5,
#   'fuel_pressure': -2.0341231867538734,
#   'inflation_pressure': -1.895525582368648,
#   'fx_pressure': 1.7861974876055335,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.5316843214978211,
#   'cfpi': 29.10971611785052,
#   'cfpi_trend': -14.16586257343522,
#   'risk_flag': 'Low'},
#  {'date': '2020-05-01',
#   'ron95': 1.25,
#   'ron97': 1.55,
#   'diesel': 1.4,
#   'ron95_budi95': 1.25,
#   'usd': 4.326,
#   'index': 112.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.5,
#   'fuel_pressure': -0.3675111647366467,
#   'inflation_pressure': -1.2519538138336548,
#   'fx_pressure': 1.2221124889575468,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.5725475931469156,
#   'cfpi': 27.24581030877477,
#   'cfpi_trend': -1.8639058090757457,
#   'risk_flag': 'Low'},
#  {'date': '2020-06-01',
#   'ron95': 1.43,
#   'ron97': 1.73,
#   'diesel': 1.61,
#   'ron95_budi95': 1.43,
#   'usd': 4.323,
#   'index': 114.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.0,
#   'fuel_pressure': 1.3148020467172157,
#   'inflation_pressure': -0.4063855811836924,
#   'fx_pressure': 0.1392805312703004,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.313461443983471,
#   'cfpi': 39.063566425409896,
#   'cfpi_trend': 11.817756116635124,
#   'risk_flag': 'Moderate'},
#  {'date': '2020-07-01',
#   'ron95': 1.69,
#   'ron97': 1.99,
#   'diesel': 1.86,
#   'ron95_budi95': 1.69,
#   'usd': 4.2815,
#   'index': 115.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.0,
#   'fuel_pressure': 1.1103186932186202,
#   'inflation_pressure': 0.2528609221170561,
#   'fx_pressure': -0.9327567444989536,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.0703642207301445,
#   'cfpi': 56.57109475734463,
#   'cfpi_trend': 17.507528331934736,
#   'risk_flag': 'Moderate'},
#  {'date': '2020-08-01',
#   'ron95': 1.68,
#   'ron97': 1.98,
#   'diesel': 1.83,
#   'ron95_budi95': 1.68,
#   'usd': 4.2425,
#   'index': 115.9,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 0.0622612783903477,
#   'inflation_pressure': 0.6137451695795877,
#   'fx_pressure': -1.205414531588397,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.1691712117379926,
#   'cfpi': 61.078000765711295,
#   'cfpi_trend': 4.506906008366663,
#   'risk_flag': 'High'},
#  {'date': '2020-09-01',
#   'ron95': 1.72,
#   'ron97': 2.02,
#   'diesel': 1.78,
#   'ron95_budi95': 1.72,
#   'usd': 4.1475,
#   'index': 115.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 0.1427115976577507,
#   'inflation_pressure': 0.7305256768851426,
#   'fx_pressure': -1.254594676084232,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.0916767997831081,
#   'cfpi': 57.5432303279943,
#   'cfpi_trend': -3.5347704377169933,
#   'risk_flag': 'Moderate'},
#  {'date': '2020-10-01',
#   'ron95': 1.68,
#   'ron97': 1.98,
#   'diesel': 1.71,
#   'ron95_budi95': 1.68,
#   'usd': 4.148,
#   'index': 115.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -0.510531293165356,
#   'inflation_pressure': 0.4186894942502942,
#   'fx_pressure': -0.7446974193080488,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.0385242437603514,
#   'cfpi': 51.60434018007938,
#   'cfpi_trend': -5.938890147914918,
#   'risk_flag': 'Moderate'},
#  {'date': '2020-11-01',
#   'ron95': 1.64,
#   'ron97': 1.94,
#   'diesel': 1.74,
#   'ron95_budi95': 1.64,
#   'usd': 4.157,
#   'index': 115.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -0.6478539703135037,
#   'inflation_pressure': -0.1264879664127413,
#   'fx_pressure': -0.1671451514682239,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.1266783424884967,
#   'cfpi': 47.5833469976388,
#   'cfpi_trend': -4.020993182440584,
#   'risk_flag': 'Moderate'},
#  {'date': '2020-12-01',
#   'ron95': 1.67,
#   'ron97': 1.97,
#   'diesel': 1.85,
#   'ron95_budi95': 1.67,
#   'usd': 4.078,
#   'index': 116.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 0.0684431172777761,
#   'inflation_pressure': 1.5508877649518258,
#   'fx_pressure': 0.5840684505248954,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.084181261521894,
#   'cfpi': 57.20133461716626,
#   'cfpi_trend': 9.617987619527462,
#   'risk_flag': 'Moderate'},
#  {'date': '2021-01-01',
#   'ron95': 1.8,
#   'ron97': 2.1,
#   'diesel': 1.98,
#   'ron95_budi95': 1.8,
#   'usd': 4.013,
#   'index': 118.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 1.7121584077598353,
#   'inflation_pressure': 1.9758610030152568,
#   'fx_pressure': -0.6145524366092355,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.4967965731502463,
#   'cfpi': 76.02205173600046,
#   'cfpi_trend': 18.820717118834203,
#   'risk_flag': 'High'},
#  {'date': '2021-02-01',
#   'ron95': 1.9,
#   'ron97': 2.2,
#   'diesel': 2.07,
#   'ron95_budi95': 1.9,
#   'usd': 4.054,
#   'index': 118.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 0.7908394361028037,
#   'inflation_pressure': 1.5038306186612604,
#   'fx_pressure': 0.3285420634514789,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.8639155630451575,
#   'cfpi': 92.76753466657016,
#   'cfpi_trend': 16.745482930569693,
#   'risk_flag': 'Severe'},
#  {'date': '2021-03-01',
#   'ron95': 2.05,
#   'ron97': 2.35,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.0535,
#   'index': 119.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 0.8308397680692831,
#   'inflation_pressure': 1.6725120863581688,
#   'fx_pressure': 1.6060412975318543,
#   'policy_pressure': 0,
#   'raw_cfpi': 1.022476255422179,
#   'cfpi': 100.0,
#   'cfpi_trend': 7.232465333429843,
#   'risk_flag': 'Severe'},
#  {'date': '2021-04-01',
#   'ron95': 2.05,
#   'ron97': 2.52,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.1465,
#   'index': 119.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -0.6791662057939689,
#   'inflation_pressure': 1.7284651772049628,
#   'fx_pressure': 1.8926537957364429,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.9216280298786428,
#   'cfpi': 95.39998669123342,
#   'cfpi_trend': -4.600013308766577,
#   'risk_flag': 'Severe'},
#  {'date': '2021-05-01',
#   'ron95': 2.05,
#   'ron97': 2.58,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.1045,
#   'index': 119.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -1.2825259832300184,
#   'inflation_pressure': 1.1659879111672362,
#   'fx_pressure': 0.735645715987352,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.7020167489067825,
#   'cfpi': 85.3828068174069,
#   'cfpi_trend': -10.01717987382652,
#   'risk_flag': 'Severe'},
#  {'date': '2021-06-01',
#   'ron95': 2.05,
#   'ron97': 2.61,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.1205,
#   'index': 119.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -1.0505716219422323,
#   'inflation_pressure': 0.3653549329416547,
#   'fx_pressure': 0.6559621041928253,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.2980353291177689,
#   'cfpi': 66.95590939300315,
#   'cfpi_trend': -18.426897424403748,
#   'risk_flag': 'High'},
#  {'date': '2021-07-01',
#   'ron95': 2.05,
#   'ron97': 2.69,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.1545,
#   'index': 119.0,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -0.649230237997772,
#   'inflation_pressure': -0.5301349010285601,
#   'fx_pressure': -0.1817061565411226,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.10076508004836,
#   'cfpi': 48.76533459787406,
#   'cfpi_trend': -18.19057479512909,
#   'risk_flag': 'Moderate'},
#  {'date': '2021-08-01',
#   'ron95': 2.05,
#   'ron97': 2.74,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.2305,
#   'index': 118.9,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -0.5130648204044508,
#   'inflation_pressure': -0.9258544616873384,
#   'fx_pressure': 1.0250639563530994,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.2485726912411205,
#   'cfpi': 42.023352029919295,
#   'cfpi_trend': -6.741982567954764,
#   'risk_flag': 'Moderate'},
#  {'date': '2021-09-01',
#   'ron95': 2.05,
#   'ron97': 2.72,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.145,
#   'index': 119.3,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -1.2757543825681543,
#   'inflation_pressure': -0.6641694480800849,
#   'fx_pressure': -0.8467669667830581,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.4913840831546411,
#   'cfpi': 30.947940159234992,
#   'cfpi_trend': -11.075411870684302,
#   'risk_flag': 'Moderate'},
#  {'date': '2021-10-01',
#   'ron95': 2.05,
#   'ron97': 2.76,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.1845,
#   'index': 120.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -0.0119503744135962,
#   'inflation_pressure': 0.0406774140882901,
#   'fx_pressure': -0.5091944495404457,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.3828938795658792,
#   'cfpi': 35.896528770381714,
#   'cfpi_trend': 4.948588611146722,
#   'risk_flag': 'Moderate'},
#  {'date': '2021-11-01',
#   'ron95': 2.05,
#   'ron97': 2.97,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.1465,
#   'index': 120.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 1.8510667198805768,
#   'inflation_pressure': 1.000816448319712,
#   'fx_pressure': -1.6093294920496282,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.0973286825967357,
#   'cfpi': 48.92207978527311,
#   'cfpi_trend': 13.025551014891391,
#   'risk_flag': 'Moderate'},
#  {'date': '2021-12-01',
#   'ron95': 2.05,
#   'ron97': 3.05,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.205,
#   'index': 121.0,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 0.067837865733297,
#   'inflation_pressure': 0.6252666812025924,
#   'fx_pressure': 0.4683965450800144,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.2751423247739266,
#   'cfpi': 65.91168552003215,
#   'cfpi_trend': 16.989605734759046,
#   'risk_flag': 'High'},
#  {'date': '2022-01-01',
#   'ron95': 2.05,
#   'ron97': 3.0,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.176,
#   'index': 121.4,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -1.1071072330855132,
#   'inflation_pressure': -0.9931325411128994,
#   'fx_pressure': -0.4816786079366051,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.0468498669068521,
#   'cfpi': 55.49852912764503,
#   'cfpi_trend': -10.413156392387124,
#   'risk_flag': 'Moderate'},
#  {'date': '2022-02-01',
#   'ron95': 2.05,
#   'ron97': 3.12,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.189,
#   'index': 121.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 0.5770335006666527,
#   'inflation_pressure': -1.2685562800207446,
#   'fx_pressure': 0.6158968623020561,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.1969651830308146,
#   'cfpi': 44.37733717264452,
#   'cfpi_trend': -11.121191955000503,
#   'risk_flag': 'Moderate'},
#  {'date': '2022-03-01',
#   'ron95': 2.05,
#   'ron97': 3.29,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.195,
#   'index': 122.1,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 0.7698731133755677,
#   'inflation_pressure': -1.0003424816483335,
#   'fx_pressure': -0.2965403961067913,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.367411856678316,
#   'cfpi': 36.60271384151789,
#   'cfpi_trend': -7.774623331126634,
#   'risk_flag': 'Moderate'},
#  {'date': '2022-04-01',
#   'ron95': 2.05,
#   'ron97': 3.91,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.209,
#   'index': 122.3,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 1.8654289760776783,
#   'inflation_pressure': -0.8596178812973172,
#   'fx_pressure': 0.5246805135167782,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.0125090826467133,
#   'cfpi': 53.932135036140416,
#   'cfpi_trend': 17.329421194622526,
#   'risk_flag': 'Moderate'},
#  {'date': '2022-05-01',
#   'ron95': 2.05,
#   'ron97': 3.94,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.359,
#   'index': 122.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -0.5655471953695163,
#   'inflation_pressure': -0.3350486675936501,
#   'fx_pressure': 1.8452545833722809,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.0891174158976057,
#   'cfpi': 57.42648856211692,
#   'cfpi_trend': 3.4943535259765,
#   'risk_flag': 'Moderate'},
#  {'date': '2022-06-01',
#   'ron95': 2.05,
#   'ron97': 4.7,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.387,
#   'index': 123.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.0,
#   'fuel_pressure': 1.4021228663279277,
#   'inflation_pressure': 1.77176298293413,
#   'fx_pressure': 1.3713913825446675,
#   'policy_pressure': 1,
#   'raw_cfpi': 0.6369501473042264,
#   'cfpi': 82.41490895192825,
#   'cfpi_trend': 24.98842038981134,
#   'risk_flag': 'Severe'},
#  {'date': '2022-07-01',
#   'ron95': 2.05,
#   'ron97': 4.84,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.409,
#   'index': 123.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.0,
#   'fuel_pressure': -0.5903946191590067,
#   'inflation_pressure': 1.8293319993387416,
#   'fx_pressure': 1.0218746973456714,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.7382248861100242,
#   'cfpi': 87.03437690823269,
#   'cfpi_trend': 4.619467956304433,
#   'risk_flag': 'Severe'},
#  {'date': '2022-08-01',
#   'ron95': 2.05,
#   'ron97': 4.55,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.4515,
#   'index': 123.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.25,
#   'fuel_pressure': -1.3282150415791267,
#   'inflation_pressure': 1.2042895540315892,
#   'fx_pressure': -0.2633988179388187,
#   'policy_pressure': 1,
#   'raw_cfpi': 0.7509706672579345,
#   'cfpi': 87.61575315550937,
#   'cfpi_trend': 0.5813762472766797,
#   'risk_flag': 'Severe'},
#  {'date': '2022-09-01',
#   'ron95': 2.05,
#   'ron97': 4.3,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.4825,
#   'index': 123.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.25,
#   'fuel_pressure': -0.9478758836126664,
#   'inflation_pressure': 0.689211208732405,
#   'fx_pressure': -0.5603520851264864,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.2108901874289302,
#   'cfpi': 62.98093800007616,
#   'cfpi_trend': -24.63481515543321,
#   'risk_flag': 'High'},
#  {'date': '2022-10-01',
#   'ron95': 2.05,
#   'ron97': 4.0,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.641,
#   'index': 124.1,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.5,
#   'fuel_pressure': -0.7756015515954797,
#   'inflation_pressure': -0.301330640025342,
#   'fx_pressure': 1.0619476894938815,
#   'policy_pressure': 1,
#   'raw_cfpi': -0.0035362809306461,
#   'cfpi': 53.200254176541264,
#   'cfpi_trend': -9.780683823534892,
#   'risk_flag': 'Moderate'},
#  {'date': '2022-11-01',
#   'ron95': 2.05,
#   'ron97': 3.95,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.731,
#   'index': 124.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.5,
#   'fuel_pressure': -0.1409507100034654,
#   'inflation_pressure': -0.6148079602517434,
#   'fx_pressure': 1.2320667227476996,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.0473401883937009,
#   'cfpi': 51.202216469680046,
#   'cfpi_trend': -1.9980377068612185,
#   'risk_flag': 'Moderate'},
#  {'date': '2022-12-01',
#   'ron95': 2.05,
#   'ron97': 3.85,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.4075,
#   'index': 124.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': 0.2228612561947827,
#   'inflation_pressure': -1.447397137041506,
#   'fx_pressure': -1.6635824768795504,
#   'policy_pressure': 1,
#   'raw_cfpi': -0.2030861408701165,
#   'cfpi': 44.098140514781335,
#   'cfpi_trend': -7.104075954898711,
#   'risk_flag': 'Moderate'},
#  {'date': '2023-01-01',
#   'ron95': 2.05,
#   'ron97': 3.35,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.413,
#   'index': 124.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': -1.6286826223505109,
#   'inflation_pressure': -1.2448161847704964,
#   'fx_pressure': -1.5298537178103435,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.6212543219861693,
#   'cfpi': 25.02413908273691,
#   'cfpi_trend': -19.074001432044422,
#   'risk_flag': 'Low'},
#  {'date': '2023-02-01',
#   'ron95': 2.05,
#   'ron97': 3.35,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.2475,
#   'index': 125.0,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': 1.0551391650152322,
#   'inflation_pressure': -0.9602356737669946,
#   'fx_pressure': -1.5282642354883975,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.7259672982768186,
#   'cfpi': 20.24784200917459,
#   'cfpi_trend': -4.776297073562319,
#   'risk_flag': 'Low'},
#  {'date': '2023-03-01',
#   'ron95': 2.05,
#   'ron97': 3.35,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.486,
#   'index': 125.1,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': 0.7828107740904001,
#   'inflation_pressure': -1.2967258378786397,
#   'fx_pressure': 0.3737558481066884,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.5665714732525066,
#   'cfpi': 27.518400440142017,
#   'cfpi_trend': 7.270558430967426,
#   'risk_flag': 'Low'},
#  {'date': '2023-04-01',
#   'ron95': 2.05,
#   'ron97': 3.35,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.409,
#   'index': 125.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': 0.5513864487100348,
#   'inflation_pressure': -1.101043376691661,
#   'fx_pressure': 0.2435894312945045,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.2135615285969313,
#   'cfpi': 43.62032424485564,
#   'cfpi_trend': 16.10192380471362,
#   'risk_flag': 'Moderate'},
#  {'date': '2023-05-01',
#   'ron95': 2.05,
#   'ron97': 3.35,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.4585,
#   'index': 125.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': 0.4993218056361608,
#   'inflation_pressure': -1.6814181222209772,
#   'fx_pressure': 1.2491949441205414,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.1681172715472072,
#   'cfpi': 45.69318359472586,
#   'cfpi_trend': 2.072859349870221,
#   'risk_flag': 'Moderate'},
#  {'date': '2023-06-01',
#   'ron95': 2.05,
#   'ron97': 3.37,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.612,
#   'index': 125.4,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 0.4889041574854924,
#   'inflation_pressure': -1.6262070544331777,
#   'fx_pressure': 0.6655816990504194,
#   'policy_pressure': 1,
#   'raw_cfpi': -0.166492351742812,
#   'cfpi': 45.76730143552683,
#   'cfpi_trend': 0.074117840800973,
#   'risk_flag': 'Moderate'},
#  {'date': '2023-07-01',
#   'ron95': 2.05,
#   'ron97': 3.37,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.679,
#   'index': 125.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4082482904618101,
#   'inflation_pressure': -1.1268612079239764,
#   'fx_pressure': 0.8892012395085446,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.2224271187561639,
#   'cfpi': 43.215936041664754,
#   'cfpi_trend': -2.5513653938620777,
#   'risk_flag': 'Moderate'},
#  {'date': '2023-08-01',
#   'ron95': 2.05,
#   'ron97': 3.37,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.516,
#   'index': 125.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4082482904618101,
#   'inflation_pressure': -0.8389292949456384,
#   'fx_pressure': -0.6506514645877927,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.3415501924310604,
#   'cfpi': 37.782347881512685,
#   'cfpi_trend': -5.43358816015207,
#   'risk_flag': 'Moderate'},
#  {'date': '2023-09-01',
#   'ron95': 2.05,
#   'ron97': 3.37,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.641,
#   'index': 125.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4082482904618101,
#   'inflation_pressure': -0.771271799880972,
#   'fx_pressure': -0.8014395382928285,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.4793244066842499,
#   'cfpi': 31.498020956038605,
#   'cfpi_trend': -6.28432692547408,
#   'risk_flag': 'Moderate'},
#  {'date': '2023-10-01',
#   'ron95': 2.05,
#   'ron97': 3.37,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.69,
#   'index': 125.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4082482904618101,
#   'inflation_pressure': -1.19405801580544,
#   'fx_pressure': -1.0094207482204214,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.6137388334523517,
#   'cfpi': 25.36694478993816,
#   'cfpi_trend': -6.131076166100446,
#   'risk_flag': 'Low'},
#  {'date': '2023-11-01',
#   'ron95': 2.05,
#   'ron97': 3.47,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.7735,
#   'index': 125.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 1.9998574281135597,
#   'inflation_pressure': -1.893948874955508,
#   'fx_pressure': 1.1296154230266924,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.3773294200883339,
#   'cfpi': 36.15034174046467,
#   'cfpi_trend': 10.783396950526509,
#   'risk_flag': 'Moderate'},
#  {'date': '2023-12-01',
#   'ron95': 2.05,
#   'ron97': 3.47,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.6775,
#   'index': 126.0,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4082482904637814,
#   'inflation_pressure': -0.4477610586606702,
#   'fx_pressure': -0.6205444026966148,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.3275268245730816,
#   'cfpi': 38.42199898526547,
#   'cfpi_trend': 2.2716572448007994,
#   'risk_flag': 'Moderate'},
#  {'date': '2024-01-01',
#   'ron95': 2.05,
#   'ron97': 3.47,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.5915,
#   'index': 126.1,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4082482904637814,
#   'inflation_pressure': -0.5337297027627613,
#   'fx_pressure': -1.25097517634776,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.2665921499267887,
#   'cfpi': 41.20142631606468,
#   'cfpi_trend': 2.779427330799209,
#   'risk_flag': 'Moderate'},
#  {'date': '2024-02-01',
#   'ron95': 2.05,
#   'ron97': 3.47,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.7305,
#   'index': 126.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4082482904637814,
#   'inflation_pressure': 0.9681848615236368,
#   'fx_pressure': -0.608965435357059,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.289392509754206,
#   'cfpi': 40.16142825873139,
#   'cfpi_trend': -1.0399980573332854,
#   'risk_flag': 'Moderate'},
#  {'date': '2024-03-01',
#   'ron95': 2.05,
#   'ron97': 3.47,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.7385,
#   'index': 126.9,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4082482904637814,
#   'inflation_pressure': 0.988646577404149,
#   'fx_pressure': 0.174044415335807,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.068839031011149,
#   'cfpi': 50.2215848162193,
#   'cfpi_trend': 10.060156557487907,
#   'risk_flag': 'Moderate'},
#  {'date': '2024-04-01',
#   'ron95': 2.05,
#   'ron97': 3.47,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.7235,
#   'index': 126.9,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4082482904637814,
#   'inflation_pressure': 0.5370107135774304,
#   'fx_pressure': 0.5753984468867928,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.1778389257775101,
#   'cfpi': 61.47336319993827,
#   'cfpi_trend': 11.251778383718973,
#   'risk_flag': 'High'},
#  {'date': '2024-05-01',
#   'ron95': 2.05,
#   'ron97': 3.47,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.7675,
#   'index': 127.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': None,
#   'inflation_pressure': 1.3720763464912231,
#   'fx_pressure': 0.1862906041071659,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.2194598250049019,
#   'cfpi': 63.371826850011935,
#   'cfpi_trend': 1.8984636500736656,
#   'risk_flag': 'High'},
#  {'date': '2024-06-01',
#   'ron95': 2.05,
#   'ron97': 3.47,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.704,
#   'index': 127.4,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': None,
#   'inflation_pressure': 0.963578795032966,
#   'fx_pressure': -0.520549171680748,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.1805589519903247,
#   'cfpi': 61.59743238124221,
#   'cfpi_trend': -1.7743944687697208,
#   'risk_flag': 'High'},
#  {'date': '2024-07-01',
#   'ron95': 2.05,
#   'ron97': 3.47,
#   'diesel': 3.35,
#   'ron95_budi95': 2.05,
#   'usd': 4.7145,
#   'index': 127.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 2.0412414523193143,
#   'inflation_pressure': 0.8504436728018265,
#   'fx_pressure': -0.4973317704212011,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.8105613670921933,
#   'cfpi': 90.33387745406696,
#   'cfpi_trend': 28.73644507282475,
#   'risk_flag': 'Severe'},
#  {'date': '2024-08-01',
#   'ron95': 2.05,
#   'ron97': 3.47,
#   'diesel': 3.35,
#   'ron95_budi95': 2.05,
#   'usd': 4.5595,
#   'index': 127.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4082482904638628,
#   'inflation_pressure': 1.1043314341797257,
#   'fx_pressure': -1.754626591594372,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.361838781798532,
#   'cfpi': 69.8661909561633,
#   'cfpi_trend': -20.46768649790367,
#   'risk_flag': 'High'},
#  {'date': '2024-09-01',
#   'ron95': 2.05,
#   'ron97': 3.42,
#   'diesel': 3.18,
#   'ron95_budi95': 2.05,
#   'usd': 4.3155,
#   'index': 127.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.6815321747940573,
#   'inflation_pressure': -0.3853915849751969,
#   'fx_pressure': -1.6487312411225772,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.0181948693976708,
#   'cfpi': 54.19148213505314,
#   'cfpi_trend': -15.674708821110151,
#   'risk_flag': 'Moderate'},
#  {'date': '2024-10-01',
#   'ron95': 2.05,
#   'ron97': 3.19,
#   'diesel': 2.95,
#   'ron95_budi95': 2.05,
#   'usd': 4.1675,
#   'index': 127.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.8266791072885298,
#   'inflation_pressure': -1.1288789843406832,
#   'fx_pressure': -1.5137337759168803,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.5672782969294516,
#   'cfpi': 27.48615992918236,
#   'cfpi_trend': -26.705322205870782,
#   'risk_flag': 'Low'},
#  {'date': '2024-11-01',
#   'ron95': 2.05,
#   'ron97': 3.19,
#   'diesel': 2.95,
#   'ron95_budi95': 2.05,
#   'usd': 4.381,
#   'index': 127.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.2072750428525112,
#   'inflation_pressure': 0.2111622871223708,
#   'fx_pressure': 0.2106750470402062,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.5203639300827027,
#   'cfpi': 29.62607573537806,
#   'cfpi_trend': 2.1399158061957024,
#   'risk_flag': 'Low'},
#  {'date': '2024-12-01',
#   'ron95': 2.05,
#   'ron97': 3.19,
#   'diesel': 2.95,
#   'ron95_budi95': 2.05,
#   'usd': 4.4395,
#   'index': 128.0,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.2072750428525112,
#   'inflation_pressure': 0.1495242750915248,
#   'fx_pressure': 1.3570989803786593,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.2101426851140147,
#   'cfpi': 43.77626873904227,
#   'cfpi_trend': 14.150193003664214,
#   'risk_flag': 'Moderate'},
#  {'date': '2025-01-01',
#   'ron95': 2.05,
#   'ron97': 3.25,
#   'diesel': 2.95,
#   'ron95_budi95': 2.05,
#   'usd': 4.47,
#   'index': 128.3,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 0.7892633317696615,
#   'inflation_pressure': 1.540687011596253,
#   'fx_pressure': 1.4684160387093073,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.4617109126261927,
#   'cfpi': 74.4216814321339,
#   'cfpi_trend': 30.64541269309162,
#   'risk_flag': 'High'},
#  {'date': '2025-02-01',
#   'ron95': 2.05,
#   'ron97': 3.43,
#   'diesel': 3.18,
#   'ron95_budi95': 2.05,
#   'usd': 4.42,
#   'index': 128.4,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 1.5660997916820505,
#   'inflation_pressure': -1.7236689167059014,
#   'fx_pressure': 0.4241639812449645,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.4275506845800012,
#   'cfpi': 72.86352309274749,
#   'cfpi_trend': -1.5581583393864094,
#   'risk_flag': 'High'},
#  {'date': '2025-03-01',
#   'ron95': 2.05,
#   'ron97': 3.43,
#   'diesel': 3.18,
#   'ron95_budi95': 2.05,
#   'usd': 4.4655,
#   'index': 128.4,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.0158518103455133,
#   'inflation_pressure': -1.384382169315188,
#   'fx_pressure': 0.1911519535083564,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.1900074541918976,
#   'cfpi': 62.02840908550144,
#   'cfpi_trend': -10.835114007246048,
#   'risk_flag': 'High'},
#  {'date': '2025-04-01',
#   'ron95': 2.05,
#   'ron97': 3.28,
#   'diesel': 3.03,
#   'ron95_budi95': 2.05,
#   'usd': 4.433,
#   'index': 128.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -1.4051873429031714,
#   'inflation_pressure': -0.5041167647574706,
#   'fx_pressure': -0.5261382863166991,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.4009683421850538,
#   'cfpi': 35.07209414945609,
#   'cfpi_trend': -26.956314936045345,
#   'risk_flag': 'Moderate'},
#  {'date': '2025-05-01',
#   'ron95': 2.05,
#   'ron97': 3.18,
#   'diesel': 2.88,
#   'ron95_budi95': 2.05,
#   'usd': 4.3175,
#   'index': 128.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.9550078631103932,
#   'inflation_pressure': -1.0825299377075326,
#   'fx_pressure': -1.1122244053843784,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.6807054525564448,
#   'cfpi': 22.31238098912101,
#   'cfpi_trend': -12.759713160335082,
#   'risk_flag': 'Low'},
#  {'date': '2025-06-01',
#   'ron95': 2.05,
#   'ron97': 3.1,
#   'diesel': 2.77,
#   'ron95_budi95': 2.05,
#   'usd': 4.239,
#   'index': 128.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.5736398659985161,
#   'inflation_pressure': -0.9922968977613142,
#   'fx_pressure': -1.2468701607155084,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.7866091173887174,
#   'cfpi': 17.48177276522815,
#   'cfpi_trend': -4.83060822389286,
#   'risk_flag': 'Low'},
#  {'date': '2025-07-01',
#   'ron95': 2.05,
#   'ron97': 3.21,
#   'diesel': 2.88,
#   'ron95_budi95': 2.05,
#   'usd': 4.1925,
#   'index': 128.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 0.8451461679713151,
#   'inflation_pressure': -1.6742813131848495,
#   'fx_pressure': -1.2374899299802185,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.7455184065286976,
#   'cfpi': 19.356052811347265,
#   'cfpi_trend': 1.8742800461191145,
#   'risk_flag': 'Low'},
#  {'date': '2025-08-01',
#   'ron95': 2.05,
#   'ron97': 3.17,
#   'diesel': 2.91,
#   'ron95_budi95': 2.05,
#   'usd': 4.2775,
#   'index': 129.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': 0.4510819326661934,
#   'inflation_pressure': 1.36160692426916,
#   'fx_pressure': 0.5749825178075223,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.2072796648409647,
#   'cfpi': 43.90686034130714,
#   'cfpi_trend': 24.550807529959872,
#   'risk_flag': 'Moderate'},
#  {'date': '2025-09-01',
#   'ron95': 2.05,
#   'ron97': 3.16,
#   'diesel': 2.88,
#   'ron95_budi95': 2.05,
#   'usd': 4.218,
#   'index': 129.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': 0.247484975842017,
#   'inflation_pressure': 1.4120230618177658,
#   'fx_pressure': 0.9106303119839494,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.299170179473945,
#   'cfpi': 67.00767358333702,
#   'cfpi_trend': 23.100813242029886,
#   'risk_flag': 'High'},
#  {'date': '2025-10-01',
#   'ron95': 2.6,
#   'ron97': 3.21,
#   'diesel': 2.93,
#   'ron95_budi95': 1.99,
#   'usd': 4.213,
#   'index': 129.4,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': 0.1631485972874338,
#   'inflation_pressure': 0.4488847578401508,
#   'fx_pressure': 1.12814033435744,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.6363818149809842,
#   'cfpi': 82.38898547894075,
#   'cfpi_trend': 15.38131189560373,
#   'risk_flag': 'Severe'},
#  {'date': '2025-11-01',
#   'ron95': 2.6,
#   'ron97': 3.2,
#   'diesel': 2.95,
#   'ron95_budi95': 1.99,
#   'usd': 4.192,
#   'index': 129.1,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': 0.1379481970308904,
#   'inflation_pressure': -0.2692251904689842,
#   'fx_pressure': 0.0970083142733198,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.3829397477957236,
#   'cfpi': 70.82867417182493,
#   'cfpi_trend': -11.560311307115825,
#   'risk_flag': 'High'},
#  {'date': '2025-12-01',
#   'ron95': 2.63,
#   'ron97': 3.26,
#   'diesel': 3.08,
#   'ron95_budi95': 1.99,
#   'usd': 4.134,
#   'index': 129.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': 1.1851592224181045,
#   'inflation_pressure': 0.2317498169519165,
#   'fx_pressure': -0.130496818509309,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.269600151852766,
#   'cfpi': 65.65888911177191,
#   'cfpi_trend': -5.169785060053016,
#   'risk_flag': 'High'},
#  {'date': '2026-01-01',
#   'ron95': 2.63,
#   'ron97': 3.26,
#   'diesel': 3.08,
#   'ron95_budi95': 1.99,
#   'usd': 3.952,
#   'index': 129.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': -0.2988320651580757,
#   'inflation_pressure': -1.087561746405737,
#   'fx_pressure': -1.865738126129461,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.1554419039195985,
#   'cfpi': 46.27134805390455,
#   'cfpi_trend': -19.387541057867367,
#   'risk_flag': 'Moderate'}]

# %%
# Out:
# [{'date': Timestamp('2017-04-01 00:00:00'),
#   'ron95': 2.13,
#   'ron97': 2.41,
#   'diesel': 2.11,
#   'ron95_budi95': 2.13,
#   'usd': 4.4265,
#   'index': 115.9,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': nan,
#   'inflation_pressure': nan,
#   'fx_pressure': nan,
#   'policy_pressure': 0,
#   'raw_cfpi': nan,
#   'cfpi': nan,
#   'cfpi_trend': nan,
#   'risk_flag': nan},
#  {'date': Timestamp('2017-05-01 00:00:00'),
#   'ron95': 2.21,
#   'ron97': 2.49,
#   'diesel': 2.14,
#   'ron95_budi95': 2.21,
#   'usd': 4.3475,
#   'index': 115.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': nan,
#   'inflation_pressure': nan,
#   'fx_pressure': nan,
#   'policy_pressure': 0,
#   'raw_cfpi': nan,
#   'cfpi': nan,
#   'cfpi_trend': nan,
#   'risk_flag': nan},
#  {'date': Timestamp('2017-06-01 00:00:00'),
#   'ron95': 2.1,
#   'ron97': 2.38,
#   'diesel': 2.02,
#   'ron95_budi95': 2.1,
#   'usd': 4.289,
#   'index': 115.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': nan,
#   'inflation_pressure': nan,
#   'fx_pressure': nan,
#   'policy_pressure': 0,
#   'raw_cfpi': nan,
#   'cfpi': nan,
#   'cfpi_trend': nan,
#   'risk_flag': nan},
#  {'date': Timestamp('2017-07-01 00:00:00'),
#   'ron95': 1.89,
#   'ron97': 2.15,
#   'diesel': 1.84,
#   'ron95_budi95': 1.89,
#   'usd': 4.294,
#   'index': 115.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': nan,
#   'inflation_pressure': nan,
#   'fx_pressure': nan,
#   'policy_pressure': 0,
#   'raw_cfpi': nan,
#   'cfpi': nan,
#   'cfpi_trend': nan,
#   'risk_flag': nan},
#  {'date': Timestamp('2017-08-01 00:00:00'),
#   'ron95': 2.03,
#   'ron97': 2.28,
#   'diesel': 1.99,
#   'ron95_budi95': 2.03,
#   'usd': 4.2775,
#   'index': 116.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': nan,
#   'inflation_pressure': nan,
#   'fx_pressure': nan,
#   'policy_pressure': 0,
#   'raw_cfpi': nan,
#   'cfpi': nan,
#   'cfpi_trend': nan,
#   'risk_flag': nan},
#  {'date': Timestamp('2017-09-01 00:00:00'),
#   'ron95': 2.16,
#   'ron97': 2.44,
#   'diesel': 2.04,
#   'ron95_budi95': 2.16,
#   'usd': 4.2695,
#   'index': 116.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': nan,
#   'inflation_pressure': nan,
#   'fx_pressure': nan,
#   'policy_pressure': 0,
#   'raw_cfpi': nan,
#   'cfpi': nan,
#   'cfpi_trend': nan,
#   'risk_flag': nan},
#  {'date': Timestamp('2017-10-01 00:00:00'),
#   'ron95': 2.16,
#   'ron97': 2.46,
#   'diesel': 2.12,
#   'ron95_budi95': 2.16,
#   'usd': 4.2275,
#   'index': 116.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 0.137655088869618,
#   'inflation_pressure': nan,
#   'fx_pressure': nan,
#   'policy_pressure': 0,
#   'raw_cfpi': nan,
#   'cfpi': nan,
#   'cfpi_trend': nan,
#   'risk_flag': nan},
#  {'date': Timestamp('2017-11-01 00:00:00'),
#   'ron95': 2.2,
#   'ron97': 2.5,
#   'diesel': 2.13,
#   'ron95_budi95': 2.2,
#   'usd': 4.2335,
#   'index': 117.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 0.1995554133323755,
#   'inflation_pressure': nan,
#   'fx_pressure': nan,
#   'policy_pressure': 0,
#   'raw_cfpi': nan,
#   'cfpi': nan,
#   'cfpi_trend': nan,
#   'risk_flag': nan},
#  {'date': Timestamp('2017-12-01 00:00:00'),
#   'ron95': 2.3,
#   'ron97': 2.58,
#   'diesel': 2.25,
#   'ron95_budi95': 2.3,
#   'usd': 4.087,
#   'index': 117.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 0.4690974477788535,
#   'inflation_pressure': nan,
#   'fx_pressure': -1.631538205736701,
#   'policy_pressure': 0,
#   'raw_cfpi': nan,
#   'cfpi': nan,
#   'cfpi_trend': nan,
#   'risk_flag': nan},
#  {'date': Timestamp('2018-01-01 00:00:00'),
#   'ron95': 2.26,
#   'ron97': 2.53,
#   'diesel': 2.26,
#   'ron95_budi95': 2.26,
#   'usd': 4.062,
#   'index': 118.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -1.3633547117622544,
#   'inflation_pressure': nan,
#   'fx_pressure': -1.127381991614233,
#   'policy_pressure': 0,
#   'raw_cfpi': nan,
#   'cfpi': nan,
#   'cfpi_trend': nan,
#   'risk_flag': nan},
#  {'date': Timestamp('2018-02-01 00:00:00'),
#   'ron95': 2.31,
#   'ron97': 2.58,
#   'diesel': 2.34,
#   'ron95_budi95': 2.31,
#   'usd': 3.8945,
#   'index': 118.1,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': 0.0865384311444102,
#   'inflation_pressure': nan,
#   'fx_pressure': -1.703215831225777,
#   'policy_pressure': 1,
#   'raw_cfpi': nan,
#   'cfpi': nan,
#   'cfpi_trend': nan,
#   'risk_flag': nan},
#  {'date': Timestamp('2018-03-01 00:00:00'),
#   'ron95': 2.2,
#   'ron97': 2.47,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 3.9305,
#   'index': 117.4,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': -1.7108202592479491,
#   'inflation_pressure': nan,
#   'fx_pressure': -0.0250174207041635,
#   'policy_pressure': 0,
#   'raw_cfpi': nan,
#   'cfpi': nan,
#   'cfpi_trend': nan,
#   'risk_flag': nan},
#  {'date': Timestamp('2018-04-01 00:00:00'),
#   'ron95': 2.2,
#   'ron97': 2.47,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 3.862,
#   'index': 117.1,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': -0.1025680916200897,
#   'inflation_pressure': nan,
#   'fx_pressure': -0.2645519169737071,
#   'policy_pressure': 0,
#   'raw_cfpi': nan,
#   'cfpi': nan,
#   'cfpi_trend': nan,
#   'risk_flag': nan},
#  {'date': Timestamp('2018-05-01 00:00:00'),
#   'ron95': 2.2,
#   'ron97': 2.47,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 3.9195,
#   'index': 117.3,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': -0.0340046338494196,
#   'inflation_pressure': nan,
#   'fx_pressure': 1.6900721194879411,
#   'policy_pressure': 0,
#   'raw_cfpi': nan,
#   'cfpi': nan,
#   'cfpi_trend': nan,
#   'risk_flag': nan},
#  {'date': Timestamp('2018-06-01 00:00:00'),
#   'ron95': 2.2,
#   'ron97': 2.47,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 3.9835,
#   'index': 116.1,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': 0.2508394539864767,
#   'inflation_pressure': nan,
#   'fx_pressure': 1.263270988541411,
#   'policy_pressure': 0,
#   'raw_cfpi': nan,
#   'cfpi': nan,
#   'cfpi_trend': nan,
#   'risk_flag': nan},
#  {'date': Timestamp('2018-07-01 00:00:00'),
#   'ron95': 2.2,
#   'ron97': 2.5,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 4.0385,
#   'index': 116.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': 0.2616404929750308,
#   'inflation_pressure': nan,
#   'fx_pressure': 1.3441319808599737,
#   'policy_pressure': 0,
#   'raw_cfpi': nan,
#   'cfpi': nan,
#   'cfpi_trend': nan,
#   'risk_flag': nan},
#  {'date': Timestamp('2018-08-01 00:00:00'),
#   'ron95': 2.2,
#   'ron97': 2.54,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 4.0655,
#   'index': 116.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': 0.5117234743256671,
#   'inflation_pressure': nan,
#   'fx_pressure': 0.8928212360922975,
#   'policy_pressure': 0,
#   'raw_cfpi': nan,
#   'cfpi': nan,
#   'cfpi_trend': nan,
#   'risk_flag': nan},
#  {'date': Timestamp('2018-09-01 00:00:00'),
#   'ron95': 2.2,
#   'ron97': 2.69,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 4.1075,
#   'index': 116.3,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': 1.9466179460353383,
#   'inflation_pressure': -1.1515844419164916,
#   'fx_pressure': 0.4951954938527114,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.2799699279103718,
#   'cfpi': 66.13188809233725,
#   'cfpi_trend': nan,
#   'risk_flag': 'High'},
#  {'date': Timestamp('2018-10-01 00:00:00'),
#   'ron95': 2.2,
#   'ron97': 2.79,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 4.1415,
#   'index': 116.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': 0.7629297891613902,
#   'inflation_pressure': -0.5518677746124766,
#   'fx_pressure': -0.0732911213929878,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.1505184596329122,
#   'cfpi': 60.22718849344725,
#   'cfpi_trend': -5.904699598889998,
#   'risk_flag': 'High'},
#  {'date': Timestamp('2018-11-01 00:00:00'),
#   'ron95': 2.2,
#   'ron97': 2.81,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 4.1845,
#   'index': 117.0,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': -0.6508818516466819,
#   'inflation_pressure': -0.8393439218082628,
#   'fx_pressure': -0.1027707773547247,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.0695173881106723,
#   'cfpi': 50.19064275780345,
#   'cfpi_trend': -10.0365457356438,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2018-12-01 00:00:00'),
#   'ron95': 2.2,
#   'ron97': 2.5,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 4.188,
#   'index': 117.1,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': -1.9402533045082453,
#   'inflation_pressure': -0.9808514150754446,
#   'fx_pressure': -1.2926452432561495,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.5574750425074994,
#   'cfpi': 27.933318028069657,
#   'cfpi_trend': -22.2573247297338,
#   'risk_flag': 'Low'},
#  {'date': Timestamp('2019-01-01 00:00:00'),
#   'ron95': 2.2,
#   'ron97': 2.5,
#   'diesel': 2.18,
#   'ron95_budi95': 2.2,
#   'usd': 4.1385,
#   'index': 116.4,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': -0.0059117440809481,
#   'inflation_pressure': -1.9563711149228733,
#   'fx_pressure': -1.832201616555236,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.9154786185454292,
#   'cfpi': 11.603618566480543,
#   'cfpi_trend': -16.32969946158911,
#   'risk_flag': 'Low'},
#  {'date': Timestamp('2019-02-01 00:00:00'),
#   'ron95': 1.98,
#   'ron97': 2.28,
#   'diesel': 2.18,
#   'ron95_budi95': 1.98,
#   'usd': 4.089,
#   'index': 116.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': -1.822955805001532,
#   'inflation_pressure': -1.0938840257990885,
#   'fx_pressure': -1.7150873501526618,
#   'policy_pressure': 0,
#   'raw_cfpi': -1.169870130866373,
#   'cfpi': 0.0,
#   'cfpi_trend': -11.603618566480543,
#   'risk_flag': 'Low'},
#  {'date': Timestamp('2019-03-01 00:00:00'),
#   'ron95': 2.08,
#   'ron97': 2.38,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.073,
#   'index': 116.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': 1.1955878946674263,
#   'inflation_pressure': 0.2067939128150053,
#   'fx_pressure': -1.2641615231796568,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.7158284746898206,
#   'cfpi': 20.71030650157454,
#   'cfpi_trend': 20.71030650157454,
#   'risk_flag': 'Low'},
#  {'date': Timestamp('2019-04-01 00:00:00'),
#   'ron95': 2.08,
#   'ron97': 2.63,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.076,
#   'index': 116.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': 0.791867160659254,
#   'inflation_pressure': 0.8460082673163948,
#   'fx_pressure': -0.5267540997035018,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.2220764884977702,
#   'cfpi': 43.23192942029264,
#   'cfpi_trend': 22.521622918718094,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2019-05-01 00:00:00'),
#   'ron95': 2.08,
#   'ron97': 2.81,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.1355,
#   'index': 117.0,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.25,
#   'fuel_pressure': 0.525973320678923,
#   'inflation_pressure': 1.0701867701320362,
#   'fx_pressure': 0.9052212038605644,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.4399785871964549,
#   'cfpi': 73.43039987345061,
#   'cfpi_trend': 30.198470453157974,
#   'risk_flag': 'High'},
#  {'date': Timestamp('2019-06-01 00:00:00'),
#   'ron95': 2.08,
#   'ron97': 2.63,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.197,
#   'index': 117.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.3797418121550271,
#   'inflation_pressure': 1.6825478178222173,
#   'fx_pressure': 1.5546522194100116,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.6425378216043622,
#   'cfpi': 82.66978082505389,
#   'cfpi_trend': 9.23938095160328,
#   'risk_flag': 'Severe'},
#  {'date': Timestamp('2019-07-01 00:00:00'),
#   'ron95': 2.08,
#   'ron97': 2.49,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.1335,
#   'index': 117.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.230684350701201,
#   'inflation_pressure': 1.1252392451715745,
#   'fx_pressure': 0.6695814425446204,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.6526153207012958,
#   'cfpi': 83.12944810938272,
#   'cfpi_trend': 0.4596672843288303,
#   'risk_flag': 'Severe'},
#  {'date': Timestamp('2019-08-01 00:00:00'),
#   'ron95': 2.08,
#   'ron97': 2.56,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.1445,
#   'index': 117.4,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.1023733138196017,
#   'inflation_pressure': 1.0065761462640994,
#   'fx_pressure': -0.0197004293949309,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.520697975583151,
#   'cfpi': 77.11227190295901,
#   'cfpi_trend': -6.017176206423713,
#   'risk_flag': 'High'},
#  {'date': Timestamp('2019-09-01 00:00:00'),
#   'ron95': 2.08,
#   'ron97': 2.5,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.222,
#   'index': 117.3,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4656713966705832,
#   'inflation_pressure': 0.5412197537706321,
#   'fx_pressure': -0.1468872733818106,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.2655141101394557,
#   'cfpi': 65.47251155123378,
#   'cfpi_trend': -11.63976035172523,
#   'risk_flag': 'High'},
#  {'date': Timestamp('2019-10-01 00:00:00'),
#   'ron95': 2.08,
#   'ron97': 2.79,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.192,
#   'index': 117.4,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 1.4259395788414324,
#   'inflation_pressure': 0.1457151615225863,
#   'fx_pressure': 0.1145352847159638,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.2798956161460933,
#   'cfpi': 66.12849849274006,
#   'cfpi_trend': 0.6559869415062849,
#   'risk_flag': 'High'},
#  {'date': Timestamp('2019-11-01 00:00:00'),
#   'ron95': 2.08,
#   'ron97': 2.59,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.172,
#   'index': 117.3,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.8609580029316706,
#   'inflation_pressure': -1.9328636515150703,
#   'fx_pressure': -0.5550907116065689,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.1745901813201259,
#   'cfpi': 45.39793327235884,
#   'cfpi_trend': -20.730565220381223,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2019-12-01 00:00:00'),
#   'ron95': 2.08,
#   'ron97': 2.66,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.1713,
#   'index': 117.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 0.3605237925581582,
#   'inflation_pressure': -0.7209956219581978,
#   'fx_pressure': -1.7767627849741747,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.3478874903384395,
#   'cfpi': 37.49328325436189,
#   'cfpi_trend': -7.904650017996957,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2020-01-01 00:00:00'),
#   'ron95': 2.08,
#   'ron97': 2.63,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.0925,
#   'index': 117.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.3302482326145,
#   'inflation_pressure': 1.2470145945511515,
#   'fx_pressure': -1.6105886099835311,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.5100295972773332,
#   'cfpi': 30.097458034726497,
#   'cfpi_trend': -7.3958252196353875,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2020-02-01 00:00:00'),
#   'ron95': 2.08,
#   'ron97': 2.41,
#   'diesel': 2.18,
#   'ron95_budi95': 2.08,
#   'usd': 4.0885,
#   'index': 117.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': -1.034917615365508,
#   'inflation_pressure': 0.9177915630389796,
#   'fx_pressure': -0.9608831698898536,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.2219019473749633,
#   'cfpi': 43.23989080467506,
#   'cfpi_trend': 13.142432769948568,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2020-03-01 00:00:00'),
#   'ron95': 2.08,
#   'ron97': 2.4,
#   'diesel': 2.13,
#   'ron95_budi95': 2.08,
#   'usd': 4.226,
#   'index': 115.9,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': -0.3060102991193275,
#   'inflation_pressure': -1.7215377867488708,
#   'fx_pressure': 0.9857231723125088,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.2211195452825115,
#   'cfpi': 43.27557869128574,
#   'cfpi_trend': 0.035687886610674,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2020-04-01 00:00:00'),
#   'ron95': 1.38,
#   'ron97': 1.68,
#   'diesel': 1.68,
#   'ron95_budi95': 1.38,
#   'usd': 4.3275,
#   'index': 112.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.5,
#   'fuel_pressure': -2.0341231867538734,
#   'inflation_pressure': -1.895525582368648,
#   'fx_pressure': 1.7861974876055335,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.5316843214978211,
#   'cfpi': 29.10971611785052,
#   'cfpi_trend': -14.16586257343522,
#   'risk_flag': 'Low'},
#  {'date': Timestamp('2020-05-01 00:00:00'),
#   'ron95': 1.25,
#   'ron97': 1.55,
#   'diesel': 1.4,
#   'ron95_budi95': 1.25,
#   'usd': 4.326,
#   'index': 112.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.5,
#   'fuel_pressure': -0.3675111647366467,
#   'inflation_pressure': -1.2519538138336548,
#   'fx_pressure': 1.2221124889575468,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.5725475931469156,
#   'cfpi': 27.24581030877477,
#   'cfpi_trend': -1.8639058090757457,
#   'risk_flag': 'Low'},
#  {'date': Timestamp('2020-06-01 00:00:00'),
#   'ron95': 1.43,
#   'ron97': 1.73,
#   'diesel': 1.61,
#   'ron95_budi95': 1.43,
#   'usd': 4.323,
#   'index': 114.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.0,
#   'fuel_pressure': 1.3148020467172157,
#   'inflation_pressure': -0.4063855811836924,
#   'fx_pressure': 0.1392805312703004,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.313461443983471,
#   'cfpi': 39.063566425409896,
#   'cfpi_trend': 11.817756116635124,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2020-07-01 00:00:00'),
#   'ron95': 1.69,
#   'ron97': 1.99,
#   'diesel': 1.86,
#   'ron95_budi95': 1.69,
#   'usd': 4.2815,
#   'index': 115.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.0,
#   'fuel_pressure': 1.1103186932186202,
#   'inflation_pressure': 0.2528609221170561,
#   'fx_pressure': -0.9327567444989536,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.0703642207301445,
#   'cfpi': 56.57109475734463,
#   'cfpi_trend': 17.507528331934736,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2020-08-01 00:00:00'),
#   'ron95': 1.68,
#   'ron97': 1.98,
#   'diesel': 1.83,
#   'ron95_budi95': 1.68,
#   'usd': 4.2425,
#   'index': 115.9,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 0.0622612783903477,
#   'inflation_pressure': 0.6137451695795877,
#   'fx_pressure': -1.205414531588397,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.1691712117379926,
#   'cfpi': 61.078000765711295,
#   'cfpi_trend': 4.506906008366663,
#   'risk_flag': 'High'},
#  {'date': Timestamp('2020-09-01 00:00:00'),
#   'ron95': 1.72,
#   'ron97': 2.02,
#   'diesel': 1.78,
#   'ron95_budi95': 1.72,
#   'usd': 4.1475,
#   'index': 115.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 0.1427115976577507,
#   'inflation_pressure': 0.7305256768851426,
#   'fx_pressure': -1.254594676084232,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.0916767997831081,
#   'cfpi': 57.5432303279943,
#   'cfpi_trend': -3.5347704377169933,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2020-10-01 00:00:00'),
#   'ron95': 1.68,
#   'ron97': 1.98,
#   'diesel': 1.71,
#   'ron95_budi95': 1.68,
#   'usd': 4.148,
#   'index': 115.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -0.510531293165356,
#   'inflation_pressure': 0.4186894942502942,
#   'fx_pressure': -0.7446974193080488,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.0385242437603514,
#   'cfpi': 51.60434018007938,
#   'cfpi_trend': -5.938890147914918,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2020-11-01 00:00:00'),
#   'ron95': 1.64,
#   'ron97': 1.94,
#   'diesel': 1.74,
#   'ron95_budi95': 1.64,
#   'usd': 4.157,
#   'index': 115.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -0.6478539703135037,
#   'inflation_pressure': -0.1264879664127413,
#   'fx_pressure': -0.1671451514682239,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.1266783424884967,
#   'cfpi': 47.5833469976388,
#   'cfpi_trend': -4.020993182440584,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2020-12-01 00:00:00'),
#   'ron95': 1.67,
#   'ron97': 1.97,
#   'diesel': 1.85,
#   'ron95_budi95': 1.67,
#   'usd': 4.078,
#   'index': 116.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 0.0684431172777761,
#   'inflation_pressure': 1.5508877649518258,
#   'fx_pressure': 0.5840684505248954,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.084181261521894,
#   'cfpi': 57.20133461716626,
#   'cfpi_trend': 9.617987619527462,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2021-01-01 00:00:00'),
#   'ron95': 1.8,
#   'ron97': 2.1,
#   'diesel': 1.98,
#   'ron95_budi95': 1.8,
#   'usd': 4.013,
#   'index': 118.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 1.7121584077598353,
#   'inflation_pressure': 1.9758610030152568,
#   'fx_pressure': -0.6145524366092355,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.4967965731502463,
#   'cfpi': 76.02205173600046,
#   'cfpi_trend': 18.820717118834203,
#   'risk_flag': 'High'},
#  {'date': Timestamp('2021-02-01 00:00:00'),
#   'ron95': 1.9,
#   'ron97': 2.2,
#   'diesel': 2.07,
#   'ron95_budi95': 1.9,
#   'usd': 4.054,
#   'index': 118.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 0.7908394361028037,
#   'inflation_pressure': 1.5038306186612604,
#   'fx_pressure': 0.3285420634514789,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.8639155630451575,
#   'cfpi': 92.76753466657016,
#   'cfpi_trend': 16.745482930569693,
#   'risk_flag': 'Severe'},
#  {'date': Timestamp('2021-03-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 2.35,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.0535,
#   'index': 119.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 0.8308397680692831,
#   'inflation_pressure': 1.6725120863581688,
#   'fx_pressure': 1.6060412975318543,
#   'policy_pressure': 0,
#   'raw_cfpi': 1.022476255422179,
#   'cfpi': 100.0,
#   'cfpi_trend': 7.232465333429843,
#   'risk_flag': 'Severe'},
#  {'date': Timestamp('2021-04-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 2.52,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.1465,
#   'index': 119.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -0.6791662057939689,
#   'inflation_pressure': 1.7284651772049628,
#   'fx_pressure': 1.8926537957364429,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.9216280298786428,
#   'cfpi': 95.39998669123342,
#   'cfpi_trend': -4.600013308766577,
#   'risk_flag': 'Severe'},
#  {'date': Timestamp('2021-05-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 2.58,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.1045,
#   'index': 119.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -1.2825259832300184,
#   'inflation_pressure': 1.1659879111672362,
#   'fx_pressure': 0.735645715987352,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.7020167489067825,
#   'cfpi': 85.3828068174069,
#   'cfpi_trend': -10.01717987382652,
#   'risk_flag': 'Severe'},
#  {'date': Timestamp('2021-06-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 2.61,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.1205,
#   'index': 119.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -1.0505716219422323,
#   'inflation_pressure': 0.3653549329416547,
#   'fx_pressure': 0.6559621041928253,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.2980353291177689,
#   'cfpi': 66.95590939300315,
#   'cfpi_trend': -18.426897424403748,
#   'risk_flag': 'High'},
#  {'date': Timestamp('2021-07-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 2.69,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.1545,
#   'index': 119.0,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -0.649230237997772,
#   'inflation_pressure': -0.5301349010285601,
#   'fx_pressure': -0.1817061565411226,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.10076508004836,
#   'cfpi': 48.76533459787406,
#   'cfpi_trend': -18.19057479512909,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2021-08-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 2.74,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.2305,
#   'index': 118.9,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -0.5130648204044508,
#   'inflation_pressure': -0.9258544616873384,
#   'fx_pressure': 1.0250639563530994,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.2485726912411205,
#   'cfpi': 42.023352029919295,
#   'cfpi_trend': -6.741982567954764,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2021-09-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 2.72,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.145,
#   'index': 119.3,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -1.2757543825681543,
#   'inflation_pressure': -0.6641694480800849,
#   'fx_pressure': -0.8467669667830581,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.4913840831546411,
#   'cfpi': 30.947940159234992,
#   'cfpi_trend': -11.075411870684302,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2021-10-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 2.76,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.1845,
#   'index': 120.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -0.0119503744135962,
#   'inflation_pressure': 0.0406774140882901,
#   'fx_pressure': -0.5091944495404457,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.3828938795658792,
#   'cfpi': 35.896528770381714,
#   'cfpi_trend': 4.948588611146722,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2021-11-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 2.97,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.1465,
#   'index': 120.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 1.8510667198805768,
#   'inflation_pressure': 1.000816448319712,
#   'fx_pressure': -1.6093294920496282,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.0973286825967357,
#   'cfpi': 48.92207978527311,
#   'cfpi_trend': 13.025551014891391,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2021-12-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.05,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.205,
#   'index': 121.0,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 0.067837865733297,
#   'inflation_pressure': 0.6252666812025924,
#   'fx_pressure': 0.4683965450800144,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.2751423247739266,
#   'cfpi': 65.91168552003215,
#   'cfpi_trend': 16.989605734759046,
#   'risk_flag': 'High'},
#  {'date': Timestamp('2022-01-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.0,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.176,
#   'index': 121.4,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -1.1071072330855132,
#   'inflation_pressure': -0.9931325411128994,
#   'fx_pressure': -0.4816786079366051,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.0468498669068521,
#   'cfpi': 55.49852912764503,
#   'cfpi_trend': -10.413156392387124,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2022-02-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.12,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.189,
#   'index': 121.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 0.5770335006666527,
#   'inflation_pressure': -1.2685562800207446,
#   'fx_pressure': 0.6158968623020561,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.1969651830308146,
#   'cfpi': 44.37733717264452,
#   'cfpi_trend': -11.121191955000503,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2022-03-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.29,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.195,
#   'index': 122.1,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 0.7698731133755677,
#   'inflation_pressure': -1.0003424816483335,
#   'fx_pressure': -0.2965403961067913,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.367411856678316,
#   'cfpi': 36.60271384151789,
#   'cfpi_trend': -7.774623331126634,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2022-04-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.91,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.209,
#   'index': 122.3,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': 1.8654289760776783,
#   'inflation_pressure': -0.8596178812973172,
#   'fx_pressure': 0.5246805135167782,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.0125090826467133,
#   'cfpi': 53.932135036140416,
#   'cfpi_trend': 17.329421194622526,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2022-05-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.94,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.359,
#   'index': 122.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 1.75,
#   'fuel_pressure': -0.5655471953695163,
#   'inflation_pressure': -0.3350486675936501,
#   'fx_pressure': 1.8452545833722809,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.0891174158976057,
#   'cfpi': 57.42648856211692,
#   'cfpi_trend': 3.4943535259765,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2022-06-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 4.7,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.387,
#   'index': 123.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.0,
#   'fuel_pressure': 1.4021228663279277,
#   'inflation_pressure': 1.77176298293413,
#   'fx_pressure': 1.3713913825446675,
#   'policy_pressure': 1,
#   'raw_cfpi': 0.6369501473042264,
#   'cfpi': 82.41490895192825,
#   'cfpi_trend': 24.98842038981134,
#   'risk_flag': 'Severe'},
#  {'date': Timestamp('2022-07-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 4.84,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.409,
#   'index': 123.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.0,
#   'fuel_pressure': -0.5903946191590067,
#   'inflation_pressure': 1.8293319993387416,
#   'fx_pressure': 1.0218746973456714,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.7382248861100242,
#   'cfpi': 87.03437690823269,
#   'cfpi_trend': 4.619467956304433,
#   'risk_flag': 'Severe'},
#  {'date': Timestamp('2022-08-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 4.55,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.4515,
#   'index': 123.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.25,
#   'fuel_pressure': -1.3282150415791267,
#   'inflation_pressure': 1.2042895540315892,
#   'fx_pressure': -0.2633988179388187,
#   'policy_pressure': 1,
#   'raw_cfpi': 0.7509706672579345,
#   'cfpi': 87.61575315550937,
#   'cfpi_trend': 0.5813762472766797,
#   'risk_flag': 'Severe'},
#  {'date': Timestamp('2022-09-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 4.3,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.4825,
#   'index': 123.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.25,
#   'fuel_pressure': -0.9478758836126664,
#   'inflation_pressure': 0.689211208732405,
#   'fx_pressure': -0.5603520851264864,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.2108901874289302,
#   'cfpi': 62.98093800007616,
#   'cfpi_trend': -24.63481515543321,
#   'risk_flag': 'High'},
#  {'date': Timestamp('2022-10-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 4.0,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.641,
#   'index': 124.1,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.5,
#   'fuel_pressure': -0.7756015515954797,
#   'inflation_pressure': -0.301330640025342,
#   'fx_pressure': 1.0619476894938815,
#   'policy_pressure': 1,
#   'raw_cfpi': -0.0035362809306461,
#   'cfpi': 53.200254176541264,
#   'cfpi_trend': -9.780683823534892,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2022-11-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.95,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.731,
#   'index': 124.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.5,
#   'fuel_pressure': -0.1409507100034654,
#   'inflation_pressure': -0.6148079602517434,
#   'fx_pressure': 1.2320667227476996,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.0473401883937009,
#   'cfpi': 51.202216469680046,
#   'cfpi_trend': -1.9980377068612185,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2022-12-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.85,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.4075,
#   'index': 124.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': 0.2228612561947827,
#   'inflation_pressure': -1.447397137041506,
#   'fx_pressure': -1.6635824768795504,
#   'policy_pressure': 1,
#   'raw_cfpi': -0.2030861408701165,
#   'cfpi': 44.098140514781335,
#   'cfpi_trend': -7.104075954898711,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2023-01-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.35,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.413,
#   'index': 124.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': -1.6286826223505109,
#   'inflation_pressure': -1.2448161847704964,
#   'fx_pressure': -1.5298537178103435,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.6212543219861693,
#   'cfpi': 25.02413908273691,
#   'cfpi_trend': -19.074001432044422,
#   'risk_flag': 'Low'},
#  {'date': Timestamp('2023-02-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.35,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.2475,
#   'index': 125.0,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': 1.0551391650152322,
#   'inflation_pressure': -0.9602356737669946,
#   'fx_pressure': -1.5282642354883975,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.7259672982768186,
#   'cfpi': 20.24784200917459,
#   'cfpi_trend': -4.776297073562319,
#   'risk_flag': 'Low'},
#  {'date': Timestamp('2023-03-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.35,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.486,
#   'index': 125.1,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': 0.7828107740904001,
#   'inflation_pressure': -1.2967258378786397,
#   'fx_pressure': 0.3737558481066884,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.5665714732525066,
#   'cfpi': 27.518400440142017,
#   'cfpi_trend': 7.270558430967426,
#   'risk_flag': 'Low'},
#  {'date': Timestamp('2023-04-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.35,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.409,
#   'index': 125.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': 0.5513864487100348,
#   'inflation_pressure': -1.101043376691661,
#   'fx_pressure': 0.2435894312945045,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.2135615285969313,
#   'cfpi': 43.62032424485564,
#   'cfpi_trend': 16.10192380471362,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2023-05-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.35,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.4585,
#   'index': 125.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': 0.4993218056361608,
#   'inflation_pressure': -1.6814181222209772,
#   'fx_pressure': 1.2491949441205414,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.1681172715472072,
#   'cfpi': 45.69318359472586,
#   'cfpi_trend': 2.072859349870221,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2023-06-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.37,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.612,
#   'index': 125.4,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 0.4889041574854924,
#   'inflation_pressure': -1.6262070544331777,
#   'fx_pressure': 0.6655816990504194,
#   'policy_pressure': 1,
#   'raw_cfpi': -0.166492351742812,
#   'cfpi': 45.76730143552683,
#   'cfpi_trend': 0.074117840800973,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2023-07-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.37,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.679,
#   'index': 125.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4082482904618101,
#   'inflation_pressure': -1.1268612079239764,
#   'fx_pressure': 0.8892012395085446,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.2224271187561639,
#   'cfpi': 43.215936041664754,
#   'cfpi_trend': -2.5513653938620777,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2023-08-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.37,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.516,
#   'index': 125.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4082482904618101,
#   'inflation_pressure': -0.8389292949456384,
#   'fx_pressure': -0.6506514645877927,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.3415501924310604,
#   'cfpi': 37.782347881512685,
#   'cfpi_trend': -5.43358816015207,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2023-09-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.37,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.641,
#   'index': 125.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4082482904618101,
#   'inflation_pressure': -0.771271799880972,
#   'fx_pressure': -0.8014395382928285,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.4793244066842499,
#   'cfpi': 31.498020956038605,
#   'cfpi_trend': -6.28432692547408,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2023-10-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.37,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.69,
#   'index': 125.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4082482904618101,
#   'inflation_pressure': -1.19405801580544,
#   'fx_pressure': -1.0094207482204214,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.6137388334523517,
#   'cfpi': 25.36694478993816,
#   'cfpi_trend': -6.131076166100446,
#   'risk_flag': 'Low'},
#  {'date': Timestamp('2023-11-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.47,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.7735,
#   'index': 125.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 1.9998574281135597,
#   'inflation_pressure': -1.893948874955508,
#   'fx_pressure': 1.1296154230266924,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.3773294200883339,
#   'cfpi': 36.15034174046467,
#   'cfpi_trend': 10.783396950526509,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2023-12-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.47,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.6775,
#   'index': 126.0,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4082482904637814,
#   'inflation_pressure': -0.4477610586606702,
#   'fx_pressure': -0.6205444026966148,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.3275268245730816,
#   'cfpi': 38.42199898526547,
#   'cfpi_trend': 2.2716572448007994,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2024-01-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.47,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.5915,
#   'index': 126.1,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4082482904637814,
#   'inflation_pressure': -0.5337297027627613,
#   'fx_pressure': -1.25097517634776,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.2665921499267887,
#   'cfpi': 41.20142631606468,
#   'cfpi_trend': 2.779427330799209,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2024-02-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.47,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.7305,
#   'index': 126.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4082482904637814,
#   'inflation_pressure': 0.9681848615236368,
#   'fx_pressure': -0.608965435357059,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.289392509754206,
#   'cfpi': 40.16142825873139,
#   'cfpi_trend': -1.0399980573332854,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2024-03-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.47,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.7385,
#   'index': 126.9,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4082482904637814,
#   'inflation_pressure': 0.988646577404149,
#   'fx_pressure': 0.174044415335807,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.068839031011149,
#   'cfpi': 50.2215848162193,
#   'cfpi_trend': 10.060156557487907,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2024-04-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.47,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.7235,
#   'index': 126.9,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4082482904637814,
#   'inflation_pressure': 0.5370107135774304,
#   'fx_pressure': 0.5753984468867928,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.1778389257775101,
#   'cfpi': 61.47336319993827,
#   'cfpi_trend': 11.251778383718973,
#   'risk_flag': 'High'},
#  {'date': Timestamp('2024-05-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.47,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.7675,
#   'index': 127.2,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': nan,
#   'inflation_pressure': 1.3720763464912231,
#   'fx_pressure': 0.1862906041071659,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.2194598250049019,
#   'cfpi': 63.371826850011935,
#   'cfpi_trend': 1.8984636500736656,
#   'risk_flag': 'High'},
#  {'date': Timestamp('2024-06-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.47,
#   'diesel': 2.15,
#   'ron95_budi95': 2.05,
#   'usd': 4.704,
#   'index': 127.4,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': nan,
#   'inflation_pressure': 0.963578795032966,
#   'fx_pressure': -0.520549171680748,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.1805589519903247,
#   'cfpi': 61.59743238124221,
#   'cfpi_trend': -1.7743944687697208,
#   'risk_flag': 'High'},
#  {'date': Timestamp('2024-07-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.47,
#   'diesel': 3.35,
#   'ron95_budi95': 2.05,
#   'usd': 4.7145,
#   'index': 127.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 2.0412414523193143,
#   'inflation_pressure': 0.8504436728018265,
#   'fx_pressure': -0.4973317704212011,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.8105613670921933,
#   'cfpi': 90.33387745406696,
#   'cfpi_trend': 28.73644507282475,
#   'risk_flag': 'Severe'},
#  {'date': Timestamp('2024-08-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.47,
#   'diesel': 3.35,
#   'ron95_budi95': 2.05,
#   'usd': 4.5595,
#   'index': 127.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.4082482904638628,
#   'inflation_pressure': 1.1043314341797257,
#   'fx_pressure': -1.754626591594372,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.361838781798532,
#   'cfpi': 69.8661909561633,
#   'cfpi_trend': -20.46768649790367,
#   'risk_flag': 'High'},
#  {'date': Timestamp('2024-09-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.42,
#   'diesel': 3.18,
#   'ron95_budi95': 2.05,
#   'usd': 4.3155,
#   'index': 127.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.6815321747940573,
#   'inflation_pressure': -0.3853915849751969,
#   'fx_pressure': -1.6487312411225772,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.0181948693976708,
#   'cfpi': 54.19148213505314,
#   'cfpi_trend': -15.674708821110151,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2024-10-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.19,
#   'diesel': 2.95,
#   'ron95_budi95': 2.05,
#   'usd': 4.1675,
#   'index': 127.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.8266791072885298,
#   'inflation_pressure': -1.1288789843406832,
#   'fx_pressure': -1.5137337759168803,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.5672782969294516,
#   'cfpi': 27.48615992918236,
#   'cfpi_trend': -26.705322205870782,
#   'risk_flag': 'Low'},
#  {'date': Timestamp('2024-11-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.19,
#   'diesel': 2.95,
#   'ron95_budi95': 2.05,
#   'usd': 4.381,
#   'index': 127.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.2072750428525112,
#   'inflation_pressure': 0.2111622871223708,
#   'fx_pressure': 0.2106750470402062,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.5203639300827027,
#   'cfpi': 29.62607573537806,
#   'cfpi_trend': 2.1399158061957024,
#   'risk_flag': 'Low'},
#  {'date': Timestamp('2024-12-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.19,
#   'diesel': 2.95,
#   'ron95_budi95': 2.05,
#   'usd': 4.4395,
#   'index': 128.0,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.2072750428525112,
#   'inflation_pressure': 0.1495242750915248,
#   'fx_pressure': 1.3570989803786593,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.2101426851140147,
#   'cfpi': 43.77626873904227,
#   'cfpi_trend': 14.150193003664214,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2025-01-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.25,
#   'diesel': 2.95,
#   'ron95_budi95': 2.05,
#   'usd': 4.47,
#   'index': 128.3,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 0.7892633317696615,
#   'inflation_pressure': 1.540687011596253,
#   'fx_pressure': 1.4684160387093073,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.4617109126261927,
#   'cfpi': 74.4216814321339,
#   'cfpi_trend': 30.64541269309162,
#   'risk_flag': 'High'},
#  {'date': Timestamp('2025-02-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.43,
#   'diesel': 3.18,
#   'ron95_budi95': 2.05,
#   'usd': 4.42,
#   'index': 128.4,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 1.5660997916820505,
#   'inflation_pressure': -1.7236689167059014,
#   'fx_pressure': 0.4241639812449645,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.4275506845800012,
#   'cfpi': 72.86352309274749,
#   'cfpi_trend': -1.5581583393864094,
#   'risk_flag': 'High'},
#  {'date': Timestamp('2025-03-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.43,
#   'diesel': 3.18,
#   'ron95_budi95': 2.05,
#   'usd': 4.4655,
#   'index': 128.4,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.0158518103455133,
#   'inflation_pressure': -1.384382169315188,
#   'fx_pressure': 0.1911519535083564,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.1900074541918976,
#   'cfpi': 62.02840908550144,
#   'cfpi_trend': -10.835114007246048,
#   'risk_flag': 'High'},
#  {'date': Timestamp('2025-04-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.28,
#   'diesel': 3.03,
#   'ron95_budi95': 2.05,
#   'usd': 4.433,
#   'index': 128.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -1.4051873429031714,
#   'inflation_pressure': -0.5041167647574706,
#   'fx_pressure': -0.5261382863166991,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.4009683421850538,
#   'cfpi': 35.07209414945609,
#   'cfpi_trend': -26.956314936045345,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2025-05-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.18,
#   'diesel': 2.88,
#   'ron95_budi95': 2.05,
#   'usd': 4.3175,
#   'index': 128.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.9550078631103932,
#   'inflation_pressure': -1.0825299377075326,
#   'fx_pressure': -1.1122244053843784,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.6807054525564448,
#   'cfpi': 22.31238098912101,
#   'cfpi_trend': -12.759713160335082,
#   'risk_flag': 'Low'},
#  {'date': Timestamp('2025-06-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.1,
#   'diesel': 2.77,
#   'ron95_budi95': 2.05,
#   'usd': 4.239,
#   'index': 128.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': -0.5736398659985161,
#   'inflation_pressure': -0.9922968977613142,
#   'fx_pressure': -1.2468701607155084,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.7866091173887174,
#   'cfpi': 17.48177276522815,
#   'cfpi_trend': -4.83060822389286,
#   'risk_flag': 'Low'},
#  {'date': Timestamp('2025-07-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.21,
#   'diesel': 2.88,
#   'ron95_budi95': 2.05,
#   'usd': 4.1925,
#   'index': 128.6,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 3.0,
#   'fuel_pressure': 0.8451461679713151,
#   'inflation_pressure': -1.6742813131848495,
#   'fx_pressure': -1.2374899299802185,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.7455184065286976,
#   'cfpi': 19.356052811347265,
#   'cfpi_trend': 1.8742800461191145,
#   'risk_flag': 'Low'},
#  {'date': Timestamp('2025-08-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.17,
#   'diesel': 2.91,
#   'ron95_budi95': 2.05,
#   'usd': 4.2775,
#   'index': 129.5,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': 0.4510819326661934,
#   'inflation_pressure': 1.36160692426916,
#   'fx_pressure': 0.5749825178075223,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.2072796648409647,
#   'cfpi': 43.90686034130714,
#   'cfpi_trend': 24.550807529959872,
#   'risk_flag': 'Moderate'},
#  {'date': Timestamp('2025-09-01 00:00:00'),
#   'ron95': 2.05,
#   'ron97': 3.16,
#   'diesel': 2.88,
#   'ron95_budi95': 2.05,
#   'usd': 4.218,
#   'index': 129.7,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': 0.247484975842017,
#   'inflation_pressure': 1.4120230618177658,
#   'fx_pressure': 0.9106303119839494,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.299170179473945,
#   'cfpi': 67.00767358333702,
#   'cfpi_trend': 23.100813242029886,
#   'risk_flag': 'High'},
#  {'date': Timestamp('2025-10-01 00:00:00'),
#   'ron95': 2.6,
#   'ron97': 3.21,
#   'diesel': 2.93,
#   'ron95_budi95': 1.99,
#   'usd': 4.213,
#   'index': 129.4,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': 0.1631485972874338,
#   'inflation_pressure': 0.4488847578401508,
#   'fx_pressure': 1.12814033435744,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.6363818149809842,
#   'cfpi': 82.38898547894075,
#   'cfpi_trend': 15.38131189560373,
#   'risk_flag': 'Severe'},
#  {'date': Timestamp('2025-11-01 00:00:00'),
#   'ron95': 2.6,
#   'ron97': 3.2,
#   'diesel': 2.95,
#   'ron95_budi95': 1.99,
#   'usd': 4.192,
#   'index': 129.1,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': 0.1379481970308904,
#   'inflation_pressure': -0.2692251904689842,
#   'fx_pressure': 0.0970083142733198,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.3829397477957236,
#   'cfpi': 70.82867417182493,
#   'cfpi_trend': -11.560311307115825,
#   'risk_flag': 'High'},
#  {'date': Timestamp('2025-12-01 00:00:00'),
#   'ron95': 2.63,
#   'ron97': 3.26,
#   'diesel': 3.08,
#   'ron95_budi95': 1.99,
#   'usd': 4.134,
#   'index': 129.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': 1.1851592224181045,
#   'inflation_pressure': 0.2317498169519165,
#   'fx_pressure': -0.130496818509309,
#   'policy_pressure': 0,
#   'raw_cfpi': 0.269600151852766,
#   'cfpi': 65.65888911177191,
#   'cfpi_trend': -5.169785060053016,
#   'risk_flag': 'High'},
#  {'date': Timestamp('2026-01-01 00:00:00'),
#   'ron95': 2.63,
#   'ron97': 3.26,
#   'diesel': 3.08,
#   'ron95_budi95': 1.99,
#   'usd': 3.952,
#   'index': 129.8,
#   'state': 'terengganu',
#   'division': 'overall',
#   'rate': 2.75,
#   'fuel_pressure': -0.2988320651580757,
#   'inflation_pressure': -1.087561746405737,
#   'fx_pressure': -1.865738126129461,
#   'policy_pressure': 0,
#   'raw_cfpi': -0.1554419039195985,
#   'cfpi': 46.27134805390455,
#   'cfpi_trend': -19.387541057867367,
#   'risk_flag': 'Moderate'}]
